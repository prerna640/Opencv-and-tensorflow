# %%
import cv2
import numpy as np

# %% [raw]
# REad display live stream from camera

# %%
cap=cv2.VideoCapture(0)#edefault 0 or -1 for your camera if you have multiple camera then apply 1 for 1st and 2 for 2nd
while(True):#ret 2 values is stored in it if frame is present then true else false 
    ret,frame = cap.read()#frame saved frame
    cv2.imshow('frame',frame)#
    
    if cv2.waitKey(1) & 0xFF == ord('q'):#if q key is press break loop and release the resources
        break
cap.release()
cv2.destroyAllWindows()

# %%
#convert image into grey scale image-

# %%
cap=cv2.VideoCapture(0)#edefault 0 or -1 for your camera if you have multiple camera then apply 1 for 1st and 2 for 2nd
while(True):#ret 2 values is stored in it if frame is present then true else false 
    ret,frame = cap.read()#frame saved frame
    cv2.imshow('frame',frame)#
    print(cap.get(cv2.CAP_PROP_FRAME_WIDTH))#640 by defalut width
    print(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))#480 default height
    if cv2.waitKey(1) & 0xFF == ord('q'):#if q key is press break loop and release the resources
        break
cap.release()
cv2.destroyAllWindows()
# Out:
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# ...

# %%
cap=cv2.VideoCapture(0)#edefault 0 or -1 for your camera if you have multiple camera then apply 1 for 1st and 2 for 2nd
fourcc=cv2.VideoWriter_fourcc(*'XVID')
out=cv2.VideoWriter('output.avi',fourcc,20.0,(640,480))#saving vedio 1st arg=vedio name,2nd 4cc code
#3rd frame per second,4th is size in tuple width height
print(cap.isOpened())
while(cap.isOpened()):#ret 2 values is stored in it if frame is present then true else false 
    ret,frame = cap.read()#frame saved frame
    cv2.imshow('frame',frame)#
    print(cap.get(cv2.CAP_PROP_FRAME_WIDTH))#640 by defalut width
    print(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))#480 default height
    out.write(frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):#if q key is press break loop and release the resources
        break
cap.release()
out.release()
cv2.destroyAllWindows()
# Out:
# True
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# ...

# %%
#draw diffrent geometric shape on image using opencv

# %%
import numpy as np
import cv2

img=cv2.imread('na.tif',0)#overwite this imag
img=cv2.line(img,(0,0),(255,255),(255,0,0),5)#parameter 1st=img,start cordinate,end cordinate,color,thixkness
img=cv2.arrowedLine(img,(0,0),(255,255),(255,0,0),5)#parameter 1st=img,start cordinate,end cordinate,color,thixkness
cv2.imshow('image',img)

cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import numpy as np
import cv2

img=cv2.imread('na.tif',0)#overwite this imag
img=cv2.line(img,(0,0),(255,255),(255,0,0),5)#parameter 1st=img,start cordinate,end cordinate,color,thixkness
img=cv2.arrowedLine(img,(0,255),(255,255),(255,0,0),5)#parameter 1st=img,start cordinate,end cordinate,color,thixkness
cv2.imshow('image',img)

cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import numpy as np
import cv2

img=cv2.imread('na.tif',0)#overwite this imag
img=cv2.line(img,(0,0),(255,255),(255,0,0),5)#parameter 1st=img,start cordinate,end cordinate,color,thixkness
img=cv2.arrowedLine(img,(0,255),(255,255),(255,0,0),5)#parameter 1st=img,start cordinate,end cordinate,color,thixkness
img=cv2.rectangle(img,(384,0),(510,128),(0,0,255),10)
img=cv2.circle(img,(447,63),63,(0,255,0),-1)
font=cv2.FONT_HERSHEY_SIMPLEX
img=cv2.putText(img,'Opencv',(10,500),font,4,(255,255,255),10,cv2.LINE_AA)#write in the image is opencv 
cv2.imshow('image',img)

cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
#create an image using the numpy zeros method

img=np.zeros([512,512,3],np.uint8)#height,width,3,dtype
import numpy as np
import cv2

#img=cv2.imread('na.tif',0)#overwite this imag
img=cv2.line(img,(0,0),(255,255),(255,0,0),5)#parameter 1st=img,start cordinate,end cordinate,color,thixkness
img=cv2.arrowedLine(img,(0,255),(255,255),(255,0,0),5)#parameter 1st=img,start cordinate,end cordinate,color,thixkness
img=cv2.rectangle(img,(384,0),(510,128),(0,0,255),10)
img=cv2.circle(img,(447,63),63,(0,255,0),-1)
font=cv2.FONT_HERSHEY_SIMPLEX
img=cv2.putText(img,'Opencv',(10,500),font,4,(255,255,255),10,cv2.LINE_AA)#write in the image is opencv 
cv2.imshow('image',img)

cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
cap=cv2.VideoCapture(0)#edefault 0 or -1 for your camera if you have multiple camera then apply 1 for 1st and 2 for 2nd
fourcc=cv2.VideoWriter_fourcc(*'XVID')
out=cv2.VideoWriter('output.avi',fourcc,20.0,(640,480))#saving vedio 1st arg=vedio name,2nd 4cc code
#3rd frame per second,4th is size in tuple width height
print(cap.isOpened())
while(cap.isOpened()):#ret 2 values is stored in it if frame is present then true else false 
    ret,frame = cap.read()#frame saved frame
    cv2.imshow('frame',frame)#
    print(cap.get(cv2.CAP_PROP_FRAME_WIDTH))#640 by defalut width this faetures also have some numbers
    print(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))#480 default height
    cap.set(3,3300)
    cap.set(4,3300)
    print(cap.get(3))
    print(cap.get(4))
    out.write(frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):#if q key is press break loop and release the resources
        break
cap.release()
out.release()
cv2.destroyAllWindows()
# Out:
# True
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0

# %%
#how to handle mouse event in opencv
#print all event present available for mouse event
import numpy as np
import cv2

events=[i for i in dir(cv2) if 'EVENT' in i]
print(events)
# Out:
# ['EVENT_FLAG_ALTKEY', 'EVENT_FLAG_CTRLKEY', 'EVENT_FLAG_LBUTTON', 'EVENT_FLAG_MBUTTON', 'EVENT_FLAG_RBUTTON', 'EVENT_FLAG_SHIFTKEY', 'EVENT_LBUTTONDBLCLK', 'EVENT_LBUTTONDOWN', 'EVENT_LBUTTONUP', 'EVENT_MBUTTONDBLCLK', 'EVENT_MBUTTONDOWN', 'EVENT_MBUTTONUP', 'EVENT_MOUSEHWHEEL', 'EVENT_MOUSEMOVE', 'EVENT_MOUSEWHEEL', 'EVENT_RBUTTONDBLCLK', 'EVENT_RBUTTONDOWN', 'EVENT_RBUTTONUP']

# %%
#call back function of mouse created
#output is black image created by numpy array
# clicking on it postion printed

def click_event(event, x, y, flags,param):
    if event == cv2.EVENT_LBUTTONDOWN:
        print(x,', ',y)
        font=cv2.FONT_HERSHEY_SIMPLEX
        strXY = str(x) + ' ,'+str(y)
        cv2.putText(img,strXY, (x,y),font, 0.5, (255,255,0),2)
        cv2.imshow('image',img)
        
img = np.zeros((512,512, 3), np.uint8)
cv2.imshow('image',img)
cv2.setMouseCallback('image',click_event)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# 144 ,  316
# 230 ,  210
# 264 ,  270
# 353 ,  329
# 265 ,  367
# 104 ,  353
# 89 ,  268
# 119 ,  207

# %%
#call back function of mouse created
#output is black image created by numpy array
# clicking on it postion printed

def click_event(event, x, y, flags,param):
    if event == cv2.EVENT_LBUTTONDOWN:
        print(x,', ',y)
        font=cv2.FONT_HERSHEY_SIMPLEX
        strXY = str(x) + ' ,'+str(y)
        cv2.putText(img,strXY, (x,y),font, 0.5, (255,255,0),2)
        cv2.imshow('image',img)
    if event == cv2.EVENT_RBUTTONDOWN:
        blue = img[y,x, 0]
        green = img[y,x, 1]
        red = img[y,x, 2]
        font = cv2.FONT_HERSHEY_SIMPLEX
        strbgr = str(blue) + ' ,'+str(green)+ ' ,'+str(red)
        cv2.putText(img,strbgr, (x,y),font, 0.5, (0,255,255),2)
        cv2.imshow('image',img)
img = np.zeros((512,512, 3), np.uint8)
cv2.imshow('image',img)
cv2.setMouseCallback('image',click_event)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# 216 ,  126
# 159 ,  260
# 228 ,  353
# 164 ,  354
# 329 ,  219

# %%
#call back function of mouse created
#output is black image created by numpy array
# clicking on it postion printed

def click_event(event, x, y, flags,param):
    if event == cv2.EVENT_LBUTTONDOWN:
        print(x,', ',y)
        font=cv2.FONT_HERSHEY_SIMPLEX
        strXY = str(x) + ' ,'+str(y)
        cv2.putText(img,strXY, (x,y),font, 0.5, (255,255,0),2)
        cv2.imshow('image',img)
    if event == cv2.EVENT_RBUTTONDOWN:
        blue = img[y,x, 0]
        green = img[y,x, 1]
        red = img[y,x, 2]
        font = cv2.FONT_HERSHEY_SIMPLEX
        strbgr = str(blue) + ' ,'+str(green)+ ' ,'+str(red)
        cv2.putText(img,strbgr, (x,y),font, 0.5, (0,255,255),2)
        cv2.imshow('image',img)
img = cv2.imread('na.tif')
cv2.imshow('image',img)
cv2.setMouseCallback('image',click_event)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# 224 ,  207
# 203 ,  236
# 341 ,  181
# 350 ,  235
# 350 ,  298
# 268 ,  318
# 211 ,  326
# 300 ,  143
# 262 ,  160

# %%
#call back function of mouse created
#output is black image created by numpy array
# clicking on it postion printed

def click_event(event, x, y, flags,param):
    if event == cv2.EVENT_LBUTTONDOWN:
        cv2.circle(img,(x,y),3,(0,0,255),-1)#image,corrdinate,radius,color,thickness
        points.append((x,y))
        if len(points) >=2:
            cv2.line(img,points[-1],points[-2],(255,0,0,5))
            
        cv2.imshow('image',img)
    
img = cv2.imread('na.tif')
cv2.imshow('image',img)
points=[]
cv2.setMouseCallback('image',click_event)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
#call back function of mouse created
#output is black image created by numpy array
# clicking on it postion printed

def click_event(event, x, y, flags,param):
    if event == cv2.EVENT_LBUTTONDOWN:
        blue=img[x,y,0]
        green=img[x,y,1]
        red=img[x,y,2]
        cv2.circle(img, (x,y),3,(0,0,255),-1)
        mycolorImage = np.zeros((512,512,3),np.uint8)
        mycolorImage[:]=[blue,green,red]
        cv2.imshow('color',mycolorImage)
        
    
img = cv2.imread('na.tif')
cv2.imshow('image',img)
points=[]
cv2.setMouseCallback('image',click_event)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import numpy as np
import cv2

img1 = cv2.imread('na.tif')
img2 = cv2.imread('text.jpg')
print(img.shape)
print(img.size)
print(img.dtype)
b,g,r=cv2.split(img)
img=cv2.merge((b,g,r))

ball=img[280:340, 330:390]
img[273:333,100:160]=ball
cv2.imshow('image',img)
points=[]
cv2.setMouseCallback('image',click_event)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# (512, 512, 3)
# 786432
# uint8
